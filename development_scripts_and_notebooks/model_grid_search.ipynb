# %%
#!c1.8
import pandas as pd
import os
import numpy as np
import pickle
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from catboost import CatBoostRegressor

# %%
#!c1.8
pd.set_option("display.max_columns", None)

# %%
#!c1.8

mapping = {
    1: "Туристская 2020 год.xlsx",
    2: "Коптевский бул. 2020 год.xlsx",
    3: "Останкино 0 2020 год.xlsx",
    4: "Глебовская 2020 год.xlsx",
    5: "Спиридоновка ул. 2020 год.xlsx",
    6: "Шаболовка 2020.xlsx",
    7: "Академика Анохина 2020.xlsx",
    8: "Бутлерова 2020.xlsx",
    9: "Пролетарский проспект 2020.xlsx",
    10: "Марьино 2020.xlsx"
}

# %%
#!c1.8
data = {}

params = {
    "skiprows": [1],
    "engine": "openpyxl"
}

for station_number, filename in mapping.items():
    path = "data/stations/" + filename
    data[station_number] = pd.read_excel(path, **params)

# %%
#!c1.8
profiles_dir = "data/ostankino_profile/"

daily_tables = {}

for file in os.scandir(profiles_dir):
    daily_table = pd.read_table(file.path, skiprows=19, decimal=",")
    date = file.name[4:12]
    daily_tables[date] = daily_table

# %%
#!c1.8
ost_profile_data = pd.concat(daily_tables)
ost_profile_data["data time"] = pd.to_datetime(ost_profile_data["data time"])
ost_profile_data.drop("Quality", axis=1, inplace = True)
ost_profile_data.rename({
    "data time": "datetime",
    "0": "t_0m",
    "50": "t_50m",
    "100": "t_100m",
    "150": "t_150m",
    "200": "t_200m",
    "250": "t_250m",
    "300": "t_300m",
    "350": "t_350m",
    "400": "t_400m",
    "450": "t_450m",
    "500": "t_500m",
    "550": "t_550m",
    "600": "t_600m",
    "OutsideTemperature": "outside_temperature"
}, axis=1, inplace =True)
ost_profile_data.reset_index(drop=True, inplace=True)
ost_profile_data = ost_profile_data.resample("20min", on="datetime").mean().reset_index()

# %%
#!c1.8
ost_253_meteo = pd.read_excel("data/ostankino_meteo.xls", skiprows=2, names=["datetime", "253_wind_direction", "253_wind_speed"])
ost_253_meteo = ost_253_meteo.resample("20min", on="datetime").mean().reset_index()

# %%
#!c1.8
ost_data = pd.merge(ost_profile_data, ost_253_meteo, how="inner", on="datetime")

# %%
#!c1.8
# Drop empty cols, rename then, cast datetime to datetime, join with city-level Ostankino data
for k, v in data.items():
    v = v.loc[:, [name for name in v.columns if "Unnamed" not in name]]
    v.dropna(axis=1, how="all", inplace=True)
    v.rename({
        "Дата и время": "datetime",
        "CO": "co",
        "NO2": "no2",
        "NO": "no",
        "PM10": "pm10",
        "PM2.5": "pm25",
        "-T-": "temperature",
        "| V |": "wind_speed",
        "_V_": "wind_direction",
        "Давление": "pressure",
        "Влажность": "humidity",
        "Осадки": "precipitation"
    }, axis=1, inplace=True)
    v["datetime"] = pd.to_datetime(v["datetime"])
    v = pd.merge(v, ost_data, how="inner", on="datetime")
    data[k] = v

# %%
#!c1.8

# Split by pollutant
pollutants = ["co", "no2", "no", "pm10", "pm25"]
for k, v in data.items():
    v_parts = {}
    for p in pollutants:
        if p in v.columns:
            cols_to_keep = ["temperature", "wind_speed", "wind_direction",\
                            "pressure", "humidity", "precipitation"] + [p] + list(ost_data.columns)
            v_part = v.loc[:, cols_to_keep]
            v_part.rename({p: "pollutant_concentration"}, axis=1,inplace=True)
            v_part = v_part.loc[v_part["pollutant_concentration"] > 0.0]
            v_parts[p] = v_part
    data[k] = v_parts

# %%
#!c1.8
    
# Add separate date and time variables
for n, dict_ in data.items():
    for pollutant, table in dict_.items():
        table["month"] = table["datetime"].dt.month
        table["day"] = table["datetime"].dt.day
        table["day_of_week"] = table["datetime"].dt.weekday
        table["hour"] = table["datetime"].dt.hour
        table.index = pd.Index(table.datetime)
        table.drop("datetime", axis=1, inplace=True)
    data[n][pollutant] = table

# Generate historical features
# Use rolling to capture some previuos and next measures
hist_features = ["temperature", "wind_speed", "wind_direction",\
                            "pressure", "humidity", "precipitation", "pollutant_concentration"]
for n, dict_ in data.items():
    for pollutant, table in dict_.items():
        for timeshift in [*range(1, 25)] + [168]:
            for feature in hist_features:
                if feature not in list(table.columns):
                    continue
                col_name = feature + "_prev_" + str(timeshift) + "h"
                if timeshift == 168:
                    window = 9
                else:
                    window_size = 6
                col_value = table[feature].rolling(window=window_size).mean().shift(3*timeshift)
                table[col_name] = col_value
        data[n][pollutant] = table

# Generate forecast features
forecast_features = ["temperature", "wind_speed", "wind_direction",\
                            "pressure", "humidity", "precipitation"]
for n, dict_ in data.items():
    for pollutant, table in dict_.items():
        for timeshift in range(1, 25):
            for feature in forecast_features:
                col_name = feature + "_forecast_" + str(timeshift) + "h"
                col_value = table[feature].rolling(window=6).mean().shift(-3*timeshift)
                table[col_name] = col_value
        data[n][pollutant] = table

# Generate target [pollution in 1…24 hours]
for n, dict_ in data.items():
    for pollutant, table in dict_.items():
        for timeshift in range(1, 25):
            col_name = "target_" + str(timeshift) + "h"
            col_value = table["pollutant_concentration"].shift(-3*timeshift)
            table[col_name] = col_value
        data[n][pollutant] = table

# %%
#!c1.8
metrics = {}
f_imp = {}
grid_search_results = {}

for station_number, station_data in data.items():
    metrics_by_pollutant = {}
    f_imp_by_pollutant = {}
    results_by_pollutant = {}
    for pollutant_name, pollutant_data in station_data.items():
        target_names = [name for name in pollutant_data.columns if "target" in name]
        train_data = pollutant_data.dropna(axis=0, subset=target_names)
        
        if train_data.shape[0] < 10000:
            print(f"Not enough data for {pollutant_name} on station {station_number}:\
            n of rows in the dataset is {train_data.shape}, skipping.")
            continue
        
        X = train_data.drop(target_names, axis=1)
        y = train_data.loc[:, target_names]
        
        param_grid = {
            "learning_rate": [0.01, 0.03, 0.05, 0.1, 0.25, 0.5, 1],
            "depth": range(2, 20, 2),
            "l2_leaf_reg": [1, 3, 5, 7, 9]}
        model =  CatBoostRegressor(loss_function="MultiRMSE", verbose=100, iterations=100)
        grid_search_results = model.grid_search(param_grid, X, y, cv=5, plot=True)
        
#         model.save_model(f"pretrained_models/{station_number}_{pollutant_name}.cbm")
        
        predictions = model.predict(X_test)
        
        predictions[predictions < 0] = 0
        
        r2 = r2_score(y_test, predictions, multioutput="raw_values")
        mse = mean_squared_error(y_test, predictions, multioutput="raw_values")
        rmse = model.get_best_score()
        metrics_by_pollutant[pollutant_name] = pd.DataFrame({"r2": r2, "mse": mse, "rmse": rmse["learn"]["MultiRMSE"]})
        
        f_imp_by_pollutant[pollutant_name] = pd.DataFrame({"features": list(X.columns),
                                                           "importance": model.get_feature_importance()})
        results_by_pollutant[pollutant_name] = results
    metrics[station_number] = pd.concat(metrics_by_pollutant)
    f_imp[station_number] = pd.concat(f_imp_by_pollutant)
    grid_search_results[statin_number] = results_by_pollutant
# Out:
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 1.7441309	test: 1.6980393	best: 1.6980393 (0)	total: 260ms	remaining: 25.8s
# 99:	learn: 1.1325723	test: 1.0855494	best: 1.0855494 (99)	total: 26.8s	remaining: 0us
#
# bestTest = 1.085549373
# bestIteration = 99
#
# 0:	loss: 1.0855494	best: 1.0855494 (0)	total: 27.2s	remaining: 2h 22m 26s
# 0:	learn: 1.7215885	test: 1.6753146	best: 1.6753146 (0)	total: 343ms	remaining: 34s
# 99:	learn: 0.9063060	test: 0.8612904	best: 0.8612904 (99)	total: 23.5s	remaining: 0us
#
# bestTest = 0.8612903547
# bestIteration = 99
#
# 1:	loss: 0.8612904	best: 0.8612904 (1)	total: 50.7s	remaining: 2h 12m 19s
# 0:	learn: 1.6992160	test: 1.6527576	best: 1.6527576 (0)	total: 382ms	remaining: 37.8s
# 99:	learn: 0.8517420	test: 0.8091972	best: 0.8091972 (99)	total: 22.9s	remaining: 0us
#
# bestTest = 0.8091971548
# bestIteration = 99
#
# 2:	loss: 0.8091972	best: 0.8091972 (2)	total: 1m 13s	remaining: 2h 7m 43s
# 0:	learn: 1.6440739	test: 1.5971454	best: 1.5971454 (0)	total: 264ms	remaining: 26.2s
# 99:	learn: 0.7896187	test: 0.7604347	best: 0.7604347 (99)	total: 20.9s	remaining: 0us
#
# bestTest = 0.7604346752
# bestIteration = 99
#
# 3:	loss: 0.7604347	best: 0.7604347 (3)	total: 1m 34s	remaining: 2h 2m 35s
# 0:	learn: 1.4865005	test: 1.4381213	best: 1.4381213 (0)	total: 262ms	remaining: 25.9s
# 99:	learn: 0.7102810	test: 0.7033440	best: 0.7033440 (99)	total: 19.8s	remaining: 0us
#
# bestTest = 0.7033440219
# bestIteration = 99
#
# 4:	loss: 0.7033440	best: 0.7033440 (4)	total: 1m 54s	remaining: 1h 58m 16s
# 0:	learn: 1.2596697	test: 1.2091854	best: 1.2091854 (0)	total: 273ms	remaining: 27.1s
# 99:	learn: 0.6706799	test: 0.6689709	best: 0.6689709 (99)	total: 20.1s	remaining: 0us
#
# bestTest = 0.6689708676
# bestIteration = 99
#
# 5:	loss: 0.6689709	best: 0.6689709 (5)	total: 2m 14s	remaining: 1h 55m 32s
# 0:	learn: 1.0431184	test: 0.9970058	best: 0.9970058 (0)	total: 264ms	remaining: 26.1s
# 99:	learn: 0.6631270	test: 0.6778242	best: 0.6778242 (99)	total: 20s	remaining: 0us
#
# bestTest = 0.6778241686
# bestIteration = 99
#
# 6:	loss: 0.6778242	best: 0.6689709 (5)	total: 2m 34s	remaining: 1h 53m 24s
# 0:	learn: 1.7441373	test: 1.6980458	best: 1.6980458 (0)	total: 267ms	remaining: 26.4s
# 99:	learn: 1.1328212	test: 1.0857993	best: 1.0857993 (99)	total: 25.1s	remaining: 0us
#
# bestTest = 1.085799262
# bestIteration = 99
#
# 7:	loss: 1.0857993	best: 0.6689709 (5)	total: 2m 59s	remaining: 1h 54m 58s
# 0:	learn: 1.7216076	test: 1.6753338	best: 1.6753338 (0)	total: 280ms	remaining: 27.7s
# 99:	learn: 0.9067972	test: 0.8622450	best: 0.8622450 (99)	total: 23.2s	remaining: 0us
#
# bestTest = 0.8622449634
# bestIteration = 99
#
# 8:	loss: 0.8622450	best: 0.6689709 (5)	total: 3m 22s	remaining: 1h 55m
# 0:	learn: 1.6992476	test: 1.6527894	best: 1.6527894 (0)	total: 274ms	remaining: 27.1s
# 99:	learn: 0.8526628	test: 0.8100884	best: 0.8100884 (99)	total: 23.1s	remaining: 0us
#
# bestTest = 0.8100884099
# bestIteration = 99
#
# 9:	loss: 0.8100884	best: 0.6689709 (5)	total: 3m 46s	remaining: 1h 54m 56s
# 0:	learn: 1.6441357	test: 1.5972077	best: 1.5972077 (0)	total: 265ms	remaining: 26.2s
# 99:	learn: 0.7906644	test: 0.7619585	best: 0.7619585 (99)	total: 24s	remaining: 0us
#
# bestTest = 0.7619584975
# bestIteration = 99
#
# 10:	loss: 0.7619585	best: 0.6689709 (5)	total: 4m 10s	remaining: 1h 55m 12s
# 0:	learn: 1.4866429	test: 1.4382651	best: 1.4382651 (0)	total: 611ms	remaining: 1m
# 99:	learn: 0.7155030	test: 0.7081862	best: 0.7081862 (99)	total: 30.8s	remaining: 0us
#
# bestTest = 0.7081861532
# bestIteration = 99
#
# 11:	loss: 0.7081862	best: 0.6689709 (5)	total: 4m 40s	remaining: 1h 58m 13s
# 0:	learn: 1.2598939	test: 1.2094126	best: 1.2094126 (0)	total: 270ms	remaining: 26.7s
# 99:	learn: 0.6774451	test: 0.6767979	best: 0.6767979 (99)	total: 20.8s	remaining: 0us
#
# bestTest = 0.676797946
# bestIteration = 99
#
# 12:	loss: 0.6767979	best: 0.6689709 (5)	total: 5m 1s	remaining: 1h 56m 48s
# 0:	learn: 1.0431194	test: 0.9969989	best: 0.9969989 (0)	total: 295ms	remaining: 29.2s
# 99:	learn: 0.6610564	test: 0.6696096	best: 0.6696096 (99)	total: 21.5s	remaining: 0us
#
# bestTest = 0.6696095649
# bestIteration = 99
#
# 13:	loss: 0.6696096	best: 0.6689709 (5)	total: 5m 23s	remaining: 1h 55m 49s
# 0:	learn: 1.7441437	test: 1.6980522	best: 1.6980522 (0)	total: 338ms	remaining: 33.5s
# 99:	learn: 1.1330693	test: 1.0860482	best: 1.0860482 (99)	total: 35.7s	remaining: 0us
#
# bestTest = 1.086048177
# bestIteration = 99
#
# 14:	loss: 1.0860482	best: 0.6689709 (5)	total: 5m 58s	remaining: 1h 59m 39s
# 0:	learn: 1.7216266	test: 1.6753530	best: 1.6753530 (0)	total: 452ms	remaining: 44.7s
# 99:	learn: 0.9072388	test: 0.8627400	best: 0.8627400 (99)	total: 29.5s	remaining: 0us
#
# bestTest = 0.8627399557
# bestIteration = 99
#
# 15:	loss: 0.8627400	best: 0.6689709 (5)	total: 6m 28s	remaining: 2h 1m
# 0:	learn: 1.6992791	test: 1.6528211	best: 1.6528211 (0)	total: 256ms	remaining: 25.3s
# 99:	learn: 0.8531647	test: 0.8110031	best: 0.8110031 (99)	total: 25.9s	remaining: 0us
#
# bestTest = 0.8110030989
# bestIteration = 99
#
# 16:	loss: 0.8110031	best: 0.6689709 (5)	total: 6m 54s	remaining: 2h 1m 4s
# 0:	learn: 1.6441974	test: 1.5972699	best: 1.5972699 (0)	total: 262ms	remaining: 25.9s
# 99:	learn: 0.7938019	test: 0.7631428	best: 0.7631428 (99)	total: 24.9s	remaining: 0us
#
# bestTest = 0.7631428158
# bestIteration = 99
#
# 17:	loss: 0.7631428	best: 0.6689709 (5)	total: 7m 19s	remaining: 2h 49s
# 0:	learn: 1.4867851	test: 1.4384088	best: 1.4384088 (0)	total: 318ms	remaining: 31.5s
# 99:	learn: 0.7225063	test: 0.7127864	best: 0.7127864 (99)	total: 21.1s	remaining: 0us
#
# bestTest = 0.7127863835
# bestIteration = 99
#
# 18:	loss: 0.7127864	best: 0.6689709 (5)	total: 7m 40s	remaining: 1h 59m 33s
# 0:	learn: 1.2601178	test: 1.2096395	best: 1.2096395 (0)	total: 333ms	remaining: 33s
# 99:	learn: 0.6798666	test: 0.6773326	best: 0.6773326 (99)	total: 22.8s	remaining: 0us
#
# bestTest = 0.6773326326
# bestIteration = 99
#
# 19:	loss: 0.6773326	best: 0.6689709 (5)	total: 8m 3s	remaining: 1h 58m 48s
# 0:	learn: 1.0431212	test: 0.9969929	best: 0.9969929 (0)	total: 424ms	remaining: 42s
# 99:	learn: 0.6608171	test: 0.6671421	best: 0.6671421 (99)	total: 22.3s	remaining: 0us
#
# bestTest = 0.6671420983
# bestIteration = 99
#
# 20:	loss: 0.6671421	best: 0.6671421 (20)	total: 8m 25s	remaining: 1h 57m 57s
# 0:	learn: 1.7441501	test: 1.6980586	best: 1.6980586 (0)	total: 258ms	remaining: 25.6s
# 99:	learn: 1.1333165	test: 1.0862961	best: 1.0862961 (99)	total: 26.4s	remaining: 0us
#
# bestTest = 1.086296135
# bestIteration = 99
#
# 21:	loss: 1.0862961	best: 0.6671421 (20)	total: 8m 51s	remaining: 1h 58m 5s
# 0:	learn: 1.7216456	test: 1.6753721	best: 1.6753721 (0)	total: 302ms	remaining: 29.9s
# 99:	learn: 0.9075172	test: 0.8631801	best: 0.8631801 (99)	total: 23.9s	remaining: 0us
#
# bestTest = 0.863180118
# bestIteration = 99
#
# 22:	loss: 0.8631801	best: 0.6671421 (20)	total: 9m 15s	remaining: 1h 57m 37s
# 0:	learn: 1.6993105	test: 1.6528527	best: 1.6528527 (0)	total: 314ms	remaining: 31.1s
# 99:	learn: 0.8533537	test: 0.8115151	best: 0.8115151 (99)	total: 35s	remaining: 0us
#
# bestTest = 0.8115150693
# bestIteration = 99
#
# 23:	loss: 0.8115151	best: 0.6671421 (20)	total: 9m 50s	remaining: 1h 59m 24s
# 0:	learn: 1.6442590	test: 1.5973319	best: 1.5973319 (0)	total: 288ms	remaining: 28.5s
# 99:	learn: 0.7964150	test: 0.7656698	best: 0.7656698 (99)	total: 25s	remaining: 0us
#
# bestTest = 0.7656698437
# bestIteration = 99
#
# 24:	loss: 0.7656698	best: 0.6671421 (20)	total: 10m 15s	remaining: 1h 59m 4s
# 0:	learn: 1.4869270	test: 1.4385522	best: 1.4385522 (0)	total: 269ms	remaining: 26.6s
# 99:	learn: 0.7257756	test: 0.7156345	best: 0.7156345 (99)	total: 22.7s	remaining: 0us
#
# bestTest = 0.7156345216
# bestIteration = 99
#
# 25:	loss: 0.7156345	best: 0.6671421 (20)	total: 10m 38s	remaining: 1h 58m 18s
# 0:	learn: 1.2603415	test: 1.2098662	best: 1.2098662 (0)	total: 312ms	remaining: 30.9s
# 99:	learn: 0.6829500	test: 0.6759704	best: 0.6759704 (99)	total: 23.9s	remaining: 0us
#
# bestTest = 0.6759704054
# bestIteration = 99
#
# 26:	loss: 0.6759704	best: 0.6671421 (20)	total: 11m 2s	remaining: 1h 57m 47s
# 0:	learn: 1.0431240	test: 0.9969879	best: 0.9969879 (0)	total: 256ms	remaining: 25.3s
# 99:	learn: 0.6614761	test: 0.6676419	best: 0.6676419 (99)	total: 20.7s	remaining: 0us
#
# bestTest = 0.6676418878
# bestIteration = 99
#
# 27:	loss: 0.6676419	best: 0.6671421 (20)	total: 11m 23s	remaining: 1h 56m 43s
# 0:	learn: 1.7441565	test: 1.6980650	best: 1.6980650 (0)	total: 273ms	remaining: 27s
# 99:	learn: 1.1335628	test: 1.0865432	best: 1.0865432 (99)	total: 26.6s	remaining: 0us
#
# bestTest = 1.086543155
# bestIteration = 99
#
# 28:	loss: 1.0865432	best: 0.6671421 (20)	total: 11m 49s	remaining: 1h 56m 40s
# 0:	learn: 1.7216646	test: 1.6753912	best: 1.6753912 (0)	total: 262ms	remaining: 25.9s
# 99:	learn: 0.9079782	test: 0.8634515	best: 0.8634515 (99)	total: 24.3s	remaining: 0us
#
# bestTest = 0.8634515436
# bestIteration = 99
#
# 29:	loss: 0.8634515	best: 0.6671421 (20)	total: 12m 14s	remaining: 1h 56m 14s
# 0:	learn: 1.6993419	test: 1.6528844	best: 1.6528844 (0)	total: 309ms	remaining: 30.6s
# 99:	learn: 0.8533945	test: 0.8118912	best: 0.8118912 (99)	total: 25.9s	remaining: 0us
#
# bestTest = 0.8118912248
# bestIteration = 99
#
# 30:	loss: 0.8118912	best: 0.6671421 (20)	total: 12m 40s	remaining: 1h 56m 3s
# 0:	learn: 1.6443205	test: 1.5973939	best: 1.5973939 (0)	total: 270ms	remaining: 26.8s
# 99:	learn: 0.7967889	test: 0.7660791	best: 0.7660791 (99)	total: 22.6s	remaining: 0us
#
# bestTest = 0.76607914
# bestIteration = 99
#
# 31:	loss: 0.7660791	best: 0.6671421 (20)	total: 13m 2s	remaining: 1h 55m 22s
# 0:	learn: 1.4870688	test: 1.4386954	best: 1.4386954 (0)	total: 284ms	remaining: 28.1s
# 99:	learn: 0.7263364	test: 0.7151136	best: 0.7151136 (99)	total: 20.8s	remaining: 0us
#
# bestTest = 0.7151136399
# bestIteration = 99
#
# 32:	loss: 0.7151136	best: 0.6671421 (20)	total: 13m 23s	remaining: 1h 54m 26s
# 0:	learn: 1.2605649	test: 1.2100927	best: 1.2100927 (0)	total: 270ms	remaining: 26.7s
# 99:	learn: 0.6847673	test: 0.6793367	best: 0.6793367 (99)	total: 22s	remaining: 0us
#
# bestTest = 0.6793367137
# bestIteration = 99
#
# 33:	loss: 0.6793367	best: 0.6671421 (20)	total: 13m 45s	remaining: 1h 53m 43s
# 0:	learn: 1.0431277	test: 0.9969838	best: 0.9969838 (0)	total: 265ms	remaining: 26.2s
# 99:	learn: 0.6651237	test: 0.6718558	best: 0.6718558 (99)	total: 22.8s	remaining: 0us
#
# bestTest = 0.6718558259
# bestIteration = 99
#
# 34:	loss: 0.6718558	best: 0.6671421 (20)	total: 14m 8s	remaining: 1h 53m 7s
# 0:	learn: 1.7435877	test: 1.6975860	best: 1.6975860 (0)	total: 855ms	remaining: 1m 24s
# 99:	learn: 1.0719918	test: 1.0278005	best: 1.0278005 (99)	total: 56.5s	remaining: 0us
#
# bestTest = 1.027800544
# bestIteration = 99
#
# 35:	loss: 1.0278005	best: 0.6671421 (20)	total: 15m 4s	remaining: 1h 56m 53s
# 0:	learn: 1.7199533	test: 1.6739480	best: 1.6739480 (0)	total: 818ms	remaining: 1m 20s
# 99:	learn: 0.8078291	test: 0.7800532	best: 0.7800532 (99)	total: 1m 7s	remaining: 0us
#
# bestTest = 0.7800531519
# bestIteration = 99
#
# 36:	loss: 0.7800532	best: 0.6671421 (20)	total: 16m 12s	remaining: 2h 1m 45s
# 0:	learn: 1.6964814	test: 1.6504688	best: 1.6504688 (0)	total: 668ms	remaining: 1m 6s
# 99:	learn: 0.7425115	test: 0.7245655	best: 0.7245655 (99)	total: 53.5s	remaining: 0us
#
# bestTest = 0.7245655127
# bestIteration = 99
#
# 37:	loss: 0.7245655	best: 0.6671421 (20)	total: 17m 5s	remaining: 2h 4m 38s
# 0:	learn: 1.6385583	test: 1.5925111	best: 1.5925111 (0)	total: 697ms	remaining: 1m 9s
# 99:	learn: 0.6744632	test: 0.6680957	best: 0.6680957 (99)	total: 51.6s	remaining: 0us
#
# bestTest = 0.6680957421
# bestIteration = 99
#
# 38:	loss: 0.6680957	best: 0.6671421 (20)	total: 17m 57s	remaining: 2h 7m 5s
# 0:	learn: 1.4723847	test: 1.4261075	best: 1.4261075 (0)	total: 701ms	remaining: 1m 9s
# 99:	learn: 0.5981499	test: 0.6060496	best: 0.6060496 (99)	total: 48.4s	remaining: 0us
#
# bestTest = 0.6060495991
# bestIteration = 99
#
# 39:	loss: 0.6060496	best: 0.6060496 (39)	total: 18m 46s	remaining: 2h 9m 1s
# 0:	learn: 1.2308090	test: 1.1839722	best: 1.1839722 (0)	total: 657ms	remaining: 1m 5s
# 99:	learn: 0.5470744	test: 0.5696718	best: 0.5696718 (99)	total: 50.3s	remaining: 0us
#
# bestTest = 0.569671783
# bestIteration = 99
#
# 40:	loss: 0.5696718	best: 0.5696718 (40)	total: 19m 36s	remaining: 2h 11m 1s
# 0:	learn: 0.9954754	test: 0.9525054	best: 0.9525054 (0)	total: 702ms	remaining: 1m 9s
# 99:	learn: 0.5440565	test: 0.6068716	best: 0.6064797 (94)	total: 48.7s	remaining: 0us
#
# bestTest = 0.6064797001
# bestIteration = 94
#
# 41:	loss: 0.6064797	best: 0.5696718 (40)	total: 20m 25s	remaining: 2h 12m 43s
# 0:	learn: 1.7436159	test: 1.6976139	best: 1.6976139 (0)	total: 675ms	remaining: 1m 6s
# 99:	learn: 1.0736038	test: 1.0291492	best: 1.0291492 (99)	total: 58.6s	remaining: 0us
#
# bestTest = 1.029149224
# bestIteration = 99
#
# 42:	loss: 1.0291492	best: 0.5696718 (40)	total: 21m 23s	remaining: 2h 15m 20s
# 0:	learn: 1.7200374	test: 1.6740310	best: 1.6740310 (0)	total: 656ms	remaining: 1m 4s
# 99:	learn: 0.8126378	test: 0.7828793	best: 0.7828793 (99)	total: 55.3s	remaining: 0us
#
# bestTest = 0.78287928
# bestIteration = 99
#
# 43:	loss: 0.7828793	best: 0.5696718 (40)	total: 22m 19s	remaining: 2h 17m 27s
# 0:	learn: 1.6966205	test: 1.6506061	best: 1.6506061 (0)	total: 682ms	remaining: 1m 7s
# 99:	learn: 0.7469805	test: 0.7289169	best: 0.7289169 (99)	total: 55.9s	remaining: 0us
#
# bestTest = 0.7289169336
# bestIteration = 99
#
# 44:	loss: 0.7289169	best: 0.5696718 (40)	total: 23m 15s	remaining: 2h 19m 30s
# 0:	learn: 1.6388314	test: 1.5927808	best: 1.5927808 (0)	total: 708ms	remaining: 1m 10s
# 99:	learn: 0.6800915	test: 0.6729958	best: 0.6729958 (99)	total: 51.7s	remaining: 0us
#
# bestTest = 0.6729957801
# bestIteration = 99
#
# 45:	loss: 0.6729958	best: 0.5696718 (40)	total: 24m 6s	remaining: 2h 21m
# 0:	learn: 1.4730184	test: 1.4267346	best: 1.4267346 (0)	total: 678ms	remaining: 1m 7s
# 99:	learn: 0.6081291	test: 0.6123158	best: 0.6123158 (99)	total: 49.2s	remaining: 0us
#
# bestTest = 0.6123157804
# bestIteration = 99
#
# 46:	loss: 0.6123158	best: 0.5696718 (40)	total: 24m 56s	remaining: 2h 22m 10s
# 0:	learn: 1.2318233	test: 1.1849778	best: 1.1849778 (0)	total: 678ms	remaining: 1m 7s
# 99:	learn: 0.5612530	test: 0.5783264	best: 0.5783264 (99)	total: 50.8s	remaining: 0us
#
# bestTest = 0.5783263662
# bestIteration = 99
#
# 47:	loss: 0.5783264	best: 0.5696718 (40)	total: 25m 46s	remaining: 2h 23m 24s
# 0:	learn: 0.9955027	test: 0.9524959	best: 0.9524959 (0)	total: 622ms	remaining: 1m 1s
# 99:	learn: 0.5480444	test: 0.5948086	best: 0.5948086 (99)	total: 54.8s	remaining: 0us
#
# bestTest = 0.5948085632
# bestIteration = 99
#
# 48:	loss: 0.5948086	best: 0.5696718 (40)	total: 26m 41s	remaining: 2h 24m 55s
# 0:	learn: 1.7436439	test: 1.6976414	best: 1.6976414 (0)	total: 599ms	remaining: 59.3s
# 99:	learn: 1.0753434	test: 1.0308671	best: 1.0308671 (99)	total: 1m 2s	remaining: 0us
#
# bestTest = 1.030867067
# bestIteration = 99
#
# 49:	loss: 1.0308671	best: 0.5696718 (40)	total: 27m 44s	remaining: 2h 27m 1s
# 0:	learn: 1.7201206	test: 1.6741131	best: 1.6741131 (0)	total: 588ms	remaining: 58.3s
# 99:	learn: 0.8148220	test: 0.7859216	best: 0.7859216 (99)	total: 54s	remaining: 0us
#
# bestTest = 0.7859216168
# bestIteration = 99
#
# 50:	loss: 0.7859216	best: 0.5696718 (40)	total: 28m 38s	remaining: 2h 28m 15s
# 0:	learn: 1.6967582	test: 1.6507421	best: 1.6507421 (0)	total: 585ms	remaining: 57.9s
# 99:	learn: 0.7518181	test: 0.7330558	best: 0.7330558 (99)	total: 1m 1s	remaining: 0us
#
# bestTest = 0.7330557868
# bestIteration = 99
#
# 51:	loss: 0.7330558	best: 0.5696718 (40)	total: 29m 39s	remaining: 2h 30m 1s
# 0:	learn: 1.6391016	test: 1.5930478	best: 1.5930478 (0)	total: 612ms	remaining: 1m
# 99:	learn: 0.6862692	test: 0.6756231	best: 0.6756231 (99)	total: 55.3s	remaining: 0us
#
# bestTest = 0.6756230699
# bestIteration = 99
#
# 52:	loss: 0.6756231	best: 0.5696718 (40)	total: 30m 35s	remaining: 2h 31m 11s
# 0:	learn: 1.4736462	test: 1.4273558	best: 1.4273558 (0)	total: 637ms	remaining: 1m 3s
# 99:	learn: 0.6137907	test: 0.6163331	best: 0.6163331 (99)	total: 56.3s	remaining: 0us
#
# bestTest = 0.6163330994
# bestIteration = 99
#
# 53:	loss: 0.6163331	best: 0.5696718 (40)	total: 31m 31s	remaining: 2h 32m 22s
# 0:	learn: 1.2328311	test: 1.1859771	best: 1.1859771 (0)	total: 769ms	remaining: 1m 16s
# 99:	learn: 0.5660194	test: 0.5797388	best: 0.5797388 (99)	total: 49s	remaining: 0us
#
# bestTest = 0.5797388005
# bestIteration = 99
#
# 54:	loss: 0.5797388	best: 0.5696718 (40)	total: 32m 20s	remaining: 2h 32m 53s
# 0:	learn: 0.9955554	test: 0.9525119	best: 0.9525119 (0)	total: 626ms	remaining: 1m 1s
# 99:	learn: 0.5578039	test: 0.5984843	best: 0.5984843 (99)	total: 45.9s	remaining: 0us
#
# bestTest = 0.5984842853
# bestIteration = 99
#
# 55:	loss: 0.5984843	best: 0.5696718 (40)	total: 33m 6s	remaining: 2h 33m 7s
# 0:	learn: 1.7436715	test: 1.6976687	best: 1.6976687 (0)	total: 642ms	remaining: 1m 3s
# 99:	learn: 1.0771440	test: 1.0325264	best: 1.0325264 (99)	total: 1m 2s	remaining: 0us
#
# bestTest = 1.032526445
# bestIteration = 99
#
# 56:	loss: 1.0325264	best: 0.5696718 (40)	total: 34m 8s	remaining: 2h 34m 32s
# 0:	learn: 1.7202029	test: 1.6741944	best: 1.6741944 (0)	total: 613ms	remaining: 1m
# 99:	learn: 0.8175270	test: 0.7884958	best: 0.7884958 (99)	total: 56.9s	remaining: 0us
#
# bestTest = 0.7884958013
# bestIteration = 99
#
# 57:	loss: 0.7884958	best: 0.5696718 (40)	total: 35m 5s	remaining: 2h 35m 29s
# 0:	learn: 1.6968945	test: 1.6508766	best: 1.6508766 (0)	total: 646ms	remaining: 1m 3s
# 99:	learn: 0.7543406	test: 0.7347851	best: 0.7347851 (99)	total: 52.5s	remaining: 0us
#
# bestTest = 0.7347850786
# bestIteration = 99
#
# 58:	loss: 0.7347851	best: 0.5696718 (40)	total: 35m 58s	remaining: 2h 36m 3s
# 0:	learn: 1.6393691	test: 1.5933121	best: 1.5933121 (0)	total: 585ms	remaining: 57.9s
# 99:	learn: 0.6885645	test: 0.6787664	best: 0.6787664 (99)	total: 48.8s	remaining: 0us
#
# bestTest = 0.6787664406
# bestIteration = 99
#
# 59:	loss: 0.6787664	best: 0.5696718 (40)	total: 36m 46s	remaining: 2h 36m 19s
# 0:	learn: 1.4742681	test: 1.4279714	best: 1.4279714 (0)	total: 623ms	remaining: 1m 1s
# 99:	learn: 0.6130884	test: 0.6154035	best: 0.6154035 (99)	total: 46s	remaining: 0us
#
# bestTest = 0.6154034697
# bestIteration = 99
#
# 60:	loss: 0.6154035	best: 0.5696718 (40)	total: 37m 32s	remaining: 2h 36m 21s
# 0:	learn: 1.2338324	test: 1.1869701	best: 1.1869701 (0)	total: 623ms	remaining: 1m 1s
# 99:	learn: 0.5653984	test: 0.5749235	best: 0.5749235 (99)	total: 46.6s	remaining: 0us
#
# bestTest = 0.5749235377
# bestIteration = 99
#
# 61:	loss: 0.5749235	best: 0.5696718 (40)	total: 38m 19s	remaining: 2h 36m 23s
# 0:	learn: 0.9956320	test: 0.9525520	best: 0.9525520 (0)	total: 588ms	remaining: 58.2s
# 99:	learn: 0.5568161	test: 0.5966260	best: 0.5966260 (99)	total: 50.2s	remaining: 0us
#
# bestTest = 0.5966259738
# bestIteration = 99
#
# 62:	loss: 0.5966260	best: 0.5696718 (40)	total: 39m 9s	remaining: 2h 36m 39s
# 0:	learn: 1.7436988	test: 1.6976956	best: 1.6976956 (0)	total: 585ms	remaining: 57.9s
# 99:	learn: 1.0787761	test: 1.0341826	best: 1.0341826 (99)	total: 1m 5s	remaining: 0us
#
# bestTest = 1.03418259
# bestIteration = 99
#
# 63:	loss: 1.0341826	best: 0.5696718 (40)	total: 40m 15s	remaining: 2h 37m 53s
# 0:	learn: 1.7202844	test: 1.6742748	best: 1.6742748 (0)	total: 596ms	remaining: 59s
# 99:	learn: 0.8198966	test: 0.7892030	best: 0.7892030 (99)	total: 1m 1s	remaining: 0us
#
# bestTest = 0.7892029779
# bestIteration = 99
#
# 64:	loss: 0.7892030	best: 0.5696718 (40)	total: 41m 16s	remaining: 2h 38m 46s
# 0:	learn: 1.6970294	test: 1.6510099	best: 1.6510099 (0)	total: 1.11s	remaining: 1m 49s
# 99:	learn: 0.7580890	test: 0.7387109	best: 0.7387109 (99)	total: 59.3s	remaining: 0us
#
# bestTest = 0.738710852
# bestIteration = 99
#
# 65:	loss: 0.7387109	best: 0.5696718 (40)	total: 42m 16s	remaining: 2h 39m 28s
# 0:	learn: 1.6396339	test: 1.5935738	best: 1.5935738 (0)	total: 601ms	remaining: 59.5s
# 99:	learn: 0.6928946	test: 0.6821208	best: 0.6821208 (99)	total: 1m 4s	remaining: 0us
#
# bestTest = 0.6821207893
# bestIteration = 99
#
# 66:	loss: 0.6821208	best: 0.5696718 (40)	total: 43m 21s	remaining: 2h 40m 27s
# 0:	learn: 1.4748843	test: 1.4285815	best: 1.4285815 (0)	total: 656ms	remaining: 1m 4s
# 99:	learn: 0.6222153	test: 0.6198942	best: 0.6198942 (99)	total: 1m 3s	remaining: 0us
#
# bestTest = 0.6198941672
# bestIteration = 99
#
# 67:	loss: 0.6198942	best: 0.5696718 (40)	total: 44m 24s	remaining: 2h 41m 19s
# 0:	learn: 1.2348272	test: 1.1879568	best: 1.1879568 (0)	total: 757ms	remaining: 1m 14s
# 99:	learn: 0.5781281	test: 0.5869643	best: 0.5869643 (99)	total: 49.1s	remaining: 0us
#
# bestTest = 0.5869642544
# bestIteration = 99
#
# 68:	loss: 0.5869643	best: 0.5696718 (40)	total: 45m 14s	remaining: 2h 41m 16s
# 0:	learn: 0.9957309	test: 0.9526145	best: 0.9526145 (0)	total: 841ms	remaining: 1m 23s
# 99:	learn: 0.5637395	test: 0.5965020	best: 0.5965020 (99)	total: 52.1s	remaining: 0us
#
# bestTest = 0.5965020392
# bestIteration = 99
#
# 69:	loss: 0.5965020	best: 0.5696718 (40)	total: 46m 6s	remaining: 2h 41m 21s
# 0:	learn: 1.7433203	test: 1.6974067	best: 1.6974067 (0)	total: 3.76s	remaining: 6m 12s
# 99:	learn: 1.0246144	test: 0.9890124	best: 0.9890124 (99)	total: 3m 59s	remaining: 0us
#
# bestTest = 0.9890123709
# bestIteration = 99
#
# 70:	loss: 0.9890124	best: 0.5696718 (40)	total: 50m 6s	remaining: 2h 52m 10s
# 0:	learn: 1.7191467	test: 1.6734065	best: 1.6734065 (0)	total: 2.05s	remaining: 3m 23s
# 99:	learn: 0.7290306	test: 0.7146982	best: 0.7146982 (99)	total: 3m 27s	remaining: 0us
#
# bestTest = 0.7146981998
# bestIteration = 99
#
# 71:	loss: 0.7146982	best: 0.5696718 (40)	total: 53m 33s	remaining: 3h 44s
# 0:	learn: 1.6951295	test: 1.6495601	best: 1.6495601 (0)	total: 2.06s	remaining: 3m 23s
# 99:	learn: 0.6580836	test: 0.6559771	best: 0.6559771 (99)	total: 4m 1s	remaining: 0us
#
# bestTest = 0.6559770927
# bestIteration = 99
#
# 72:	loss: 0.6559771	best: 0.5696718 (40)	total: 57m 34s	remaining: 3h 10m 52s
# 0:	learn: 1.6358166	test: 1.5906625	best: 1.5906625 (0)	total: 2.5s	remaining: 4m 7s
# 99:	learn: 0.5833301	test: 0.5919649	best: 0.5919649 (99)	total: 3m 44s	remaining: 0us
#
# bestTest = 0.5919648993
# bestIteration = 99
#
# 73:	loss: 0.5919649	best: 0.5696718 (40)	total: 1h 1m 18s	remaining: 3h 19m 40s
# 0:	learn: 1.4652360	test: 1.4212370	best: 1.4212370 (0)	total: 2.12s	remaining: 3m 30s
# 99:	learn: 0.4915726	test: 0.5242260	best: 0.5242260 (99)	total: 3m 35s	remaining: 0us
#
# bestTest = 0.5242260112
# bestIteration = 99
#
# 74:	loss: 0.5242260	best: 0.5242260 (74)	total: 1h 4m 54s	remaining: 3h 27m 41s
# 0:	learn: 1.2156079	test: 1.1733994	best: 1.1733994 (0)	total: 2.07s	remaining: 3m 25s
# 99:	learn: 0.4466372	test: 0.5197572	best: 0.5197572 (99)	total: 3m 29s	remaining: 0us
#
# bestTest = 0.5197572128
# bestIteration = 99
#
# 75:	loss: 0.5197572	best: 0.5197572 (75)	total: 1h 8m 24s	remaining: 3h 35m 7s
# 0:	learn: 0.9673899	test: 0.9320227	best: 0.9320227 (0)	total: 2.1s	remaining: 3m 27s
# 99:	learn: 0.4376207	test: 0.5706656	best: 0.5706656 (99)	total: 3m 16s	remaining: 0us
#
# bestTest = 0.570665617
# bestIteration = 99
#
# 76:	loss: 0.5706656	best: 0.5197572 (75)	total: 1h 11m 40s	remaining: 3h 41m 31s
# 0:	learn: 1.7434375	test: 1.6975196	best: 1.6975196 (0)	total: 2.04s	remaining: 3m 21s
# 99:	learn: 1.0325167	test: 0.9963376	best: 0.9963376 (99)	total: 3m 20s	remaining: 0us
#
# bestTest = 0.9963376091
# bestIteration = 99
#
# 77:	loss: 0.9963376	best: 0.5197572 (75)	total: 1h 15m	remaining: 3h 47m 54s
# 0:	learn: 1.7194963	test: 1.6737429	best: 1.6737429 (0)	total: 2.04s	remaining: 3m 22s
# 99:	learn: 0.7379225	test: 0.7218450	best: 0.7218450 (99)	total: 3m 18s	remaining: 0us
#
# bestTest = 0.7218449811
# bestIteration = 99
#
# 78:	loss: 0.7218450	best: 0.5197572 (75)	total: 1h 18m 18s	remaining: 3h 53m 56s
# 0:	learn: 1.6957088	test: 1.6501172	best: 1.6501172 (0)	total: 2.04s	remaining: 3m 21s
# 99:	learn: 0.6660062	test: 0.6622134	best: 0.6622134 (99)	total: 3m 17s	remaining: 0us
#
# bestTest = 0.6622133639
# bestIteration = 99
#
# 79:	loss: 0.6622134	best: 0.5197572 (75)	total: 1h 21m 35s	remaining: 3h 59m 41s
# 0:	learn: 1.6369565	test: 1.5917569	best: 1.5917569 (0)	total: 2.03s	remaining: 3m 20s
# 99:	learn: 0.5905293	test: 0.5955559	best: 0.5955559 (99)	total: 3m 16s	remaining: 0us
#
# bestTest = 0.595555942
# bestIteration = 99
#
# 80:	loss: 0.5955559	best: 0.5197572 (75)	total: 1h 24m 52s	remaining: 4h 5m 13s
# 0:	learn: 1.4679101	test: 1.4237884	best: 1.4237884 (0)	total: 2s	remaining: 3m 18s
# 99:	learn: 0.5109192	test: 0.5357616	best: 0.5357616 (99)	total: 3m 13s	remaining: 0us
#
# bestTest = 0.5357615724
# bestIteration = 99
#
# 81:	loss: 0.5357616	best: 0.5197572 (75)	total: 1h 28m 6s	remaining: 4h 10m 21s
# 0:	learn: 1.2200188	test: 1.1775208	best: 1.1775208 (0)	total: 2.02s	remaining: 3m 20s
# 99:	learn: 0.4676333	test: 0.5226512	best: 0.5226512 (99)	total: 3m 12s	remaining: 0us
#
# bestTest = 0.5226511635
# bestIteration = 99
#
# 82:	loss: 0.5226512	best: 0.5197572 (75)	total: 1h 31m 19s	remaining: 4h 15m 15s
# 0:	learn: 0.9682742	test: 0.9320567	best: 0.9320567 (0)	total: 2.02s	remaining: 3m 19s
# 99:	learn: 0.4535126	test: 0.5686020	best: 0.5686020 (99)	total: 3m 15s	remaining: 0us
#
# bestTest = 0.568602047
# bestIteration = 99
#
# 83:	loss: 0.5686020	best: 0.5197572 (75)	total: 1h 34m 34s	remaining: 4h 20m 5s
# 0:	learn: 1.7435467	test: 1.6976260	best: 1.6976260 (0)	total: 2.01s	remaining: 3m 19s
# 99:	learn: 1.0389098	test: 1.0017572	best: 1.0017572 (99)	total: 3m 18s	remaining: 0us
#
# bestTest = 1.00175724
# bestIteration = 99
#
# 84:	loss: 1.0017572	best: 0.5197572 (75)	total: 1h 37m 53s	remaining: 4h 24m 51s
# 0:	learn: 1.7198220	test: 1.6740603	best: 1.6740603 (0)	total: 1.98s	remaining: 3m 15s
# 99:	learn: 0.7439642	test: 0.7273403	best: 0.7273403 (99)	total: 3m 16s	remaining: 0us
#
# bestTest = 0.7273402675
# bestIteration = 99
#
# 85:	loss: 0.7273403	best: 0.5197572 (75)	total: 1h 41m 9s	remaining: 4h 29m 21s
# 0:	learn: 1.6962485	test: 1.6506430	best: 1.6506430 (0)	total: 2s	remaining: 3m 18s
# 99:	learn: 0.6742533	test: 0.6688819	best: 0.6688819 (99)	total: 3m 15s	remaining: 0us
#
# bestTest = 0.6688819438
# bestIteration = 99
#
# 86:	loss: 0.6688819	best: 0.5197572 (75)	total: 1h 44m 24s	remaining: 4h 33m 38s
# 0:	learn: 1.6380193	test: 1.5927915	best: 1.5927915 (0)	total: 2.02s	remaining: 3m 19s
# 99:	learn: 0.5985847	test: 0.6036597	best: 0.6036597 (99)	total: 3m 15s	remaining: 0us
#
# bestTest = 0.6036597435
# bestIteration = 99
#
# 87:	loss: 0.6036597	best: 0.5197572 (75)	total: 1h 47m 40s	remaining: 4h 37m 43s
# 0:	learn: 1.4704107	test: 1.4262136	best: 1.4262136 (0)	total: 1.99s	remaining: 3m 16s
# 99:	learn: 0.5243732	test: 0.5420268	best: 0.5420268 (99)	total: 3m 12s	remaining: 0us
#
# bestTest = 0.5420267992
# bestIteration = 99
#
# 88:	loss: 0.5420268	best: 0.5197572 (75)	total: 1h 50m 52s	remaining: 4h 41m 32s
# 0:	learn: 1.2241847	test: 1.1815090	best: 1.1815090 (0)	total: 2.01s	remaining: 3m 18s
# 99:	learn: 0.4830758	test: 0.5220784	best: 0.5220784 (99)	total: 3m 11s	remaining: 0us
#
# bestTest = 0.5220783864
# bestIteration = 99
#
# 89:	loss: 0.5220784	best: 0.5197572 (75)	total: 1h 54m 3s	remaining: 4h 45m 9s
# 0:	learn: 0.9694672	test: 0.9326761	best: 0.9326761 (0)	total: 2.01s	remaining: 3m 19s
# 99:	learn: 0.4596383	test: 0.5556770	best: 0.5556770 (99)	total: 3m 11s	remaining: 0us
#
# bestTest = 0.5556769845
# bestIteration = 99
#
# 90:	loss: 0.5556770	best: 0.5197572 (75)	total: 1h 57m 15s	remaining: 4h 48m 38s
# 0:	learn: 1.7436500	test: 1.6977270	best: 1.6977270 (0)	total: 2.01s	remaining: 3m 19s
# 99:	learn: 1.0440651	test: 1.0065711	best: 1.0065711 (99)	total: 3m 17s	remaining: 0us
#
# bestTest = 1.006571124
# bestIteration = 99
#
# 91:	loss: 1.0065711	best: 0.5197572 (75)	total: 2h 33s	remaining: 4h 52m 12s
# 0:	learn: 1.7201302	test: 1.6743619	best: 1.6743619 (0)	total: 2.03s	remaining: 3m 21s
# 99:	learn: 0.7493379	test: 0.7325007	best: 0.7325007 (99)	total: 3m 19s	remaining: 0us
#
# bestTest = 0.7325006789
# bestIteration = 99
#
# 92:	loss: 0.7325007	best: 0.5197572 (75)	total: 2h 3m 52s	remaining: 4h 55m 42s
# 0:	learn: 1.6967594	test: 1.6511428	best: 1.6511428 (0)	total: 2.01s	remaining: 3m 19s
# 99:	learn: 0.6798378	test: 0.6740706	best: 0.6740706 (99)	total: 3m 15s	remaining: 0us
#
# bestTest = 0.6740705591
# bestIteration = 99
#
# 93:	loss: 0.6740706	best: 0.5197572 (75)	total: 2h 7m 8s	remaining: 4h 58m 54s
# 0:	learn: 1.6390260	test: 1.5937758	best: 1.5937758 (0)	total: 1.98s	remaining: 3m 15s
# 99:	learn: 0.6089137	test: 0.6126515	best: 0.6126515 (99)	total: 3m 14s	remaining: 0us
#
# bestTest = 0.6126515405
# bestIteration = 99
#
# 94:	loss: 0.6126515	best: 0.5197572 (75)	total: 2h 10m 23s	remaining: 5h 1m 56s
# 0:	learn: 1.4727850	test: 1.4285303	best: 1.4285303 (0)	total: 2s	remaining: 3m 18s
# 99:	learn: 0.5323969	test: 0.5481945	best: 0.5481945 (99)	total: 3m 12s	remaining: 0us
#
# bestTest = 0.5481944556
# bestIteration = 99
#
# 95:	loss: 0.5481945	best: 0.5197572 (75)	total: 2h 13m 35s	remaining: 5h 4m 44s
# 0:	learn: 1.2281709	test: 1.1853677	best: 1.1853677 (0)	total: 2.01s	remaining: 3m 19s
# 99:	learn: 0.4831976	test: 0.5263893	best: 0.5263893 (99)	total: 3m 12s	remaining: 0us
#
# bestTest = 0.5263893215
# bestIteration = 99
#
# 96:	loss: 0.5263893	best: 0.5197572 (75)	total: 2h 16m 47s	remaining: 5h 7m 26s
# 0:	learn: 0.9708849	test: 0.9336893	best: 0.9336893 (0)	total: 1.98s	remaining: 3m 16s
# 99:	learn: 0.4603167	test: 0.5591751	best: 0.5591751 (99)	total: 3m 12s	remaining: 0us
#
# bestTest = 0.5591750763
# bestIteration = 99
#
# 97:	loss: 0.5591751	best: 0.5197572 (75)	total: 2h 20m	remaining: 5h 10m
# 0:	learn: 1.7437484	test: 1.6978235	best: 1.6978235 (0)	total: 2.02s	remaining: 3m 19s
# 99:	learn: 1.0488890	test: 1.0109145	best: 1.0109145 (99)	total: 3m 17s	remaining: 0us
#
# bestTest = 1.010914471
# bestIteration = 99
#
# 98:	loss: 1.0109145	best: 0.5197572 (75)	total: 2h 23m 17s	remaining: 5h 12m 38s
# 0:	learn: 1.7204242	test: 1.6746499	best: 1.6746499 (0)	total: 2.01s	remaining: 3m 18s
# 99:	learn: 0.7552130	test: 0.7365950	best: 0.7365950 (99)	total: 3m 17s	remaining: 0us
#
# bestTest = 0.7365950417
# bestIteration = 99
#
# 99:	loss: 0.7365950	best: 0.5197572 (75)	total: 2h 26m 35s	remaining: 5h 15m 9s
# 0:	learn: 1.6972468	test: 1.6516203	best: 1.6516203 (0)	total: 2.02s	remaining: 3m 20s
# 99:	learn: 0.6853707	test: 0.6788656	best: 0.6788656 (99)	total: 3m 16s	remaining: 0us
#
# bestTest = 0.6788655746
# bestIteration = 99
#
# 100:	loss: 0.6788656	best: 0.5197572 (75)	total: 2h 29m 51s	remaining: 5h 17m 31s
# 0:	learn: 1.6399869	test: 1.5947170	best: 1.5947170 (0)	total: 2.06s	remaining: 3m 23s
# 99:	learn: 0.6106068	test: 0.6118759	best: 0.6118759 (99)	total: 3m 17s	remaining: 0us
#
# bestTest = 0.6118759345
# bestIteration = 99
#
# 101:	loss: 0.6118759	best: 0.5197572 (75)	total: 2h 33m 8s	remaining: 5h 19m 48s
# 0:	learn: 1.4750554	test: 1.4307520	best: 1.4307520 (0)	total: 2.05s	remaining: 3m 22s
# 99:	learn: 0.5399565	test: 0.5517864	best: 0.5517864 (99)	total: 3m 20s	remaining: 0us
#
# bestTest = 0.5517863602
# bestIteration = 99
#
# 102:	loss: 0.5517864	best: 0.5197572 (75)	total: 2h 36m 29s	remaining: 5h 22m 5s
# 0:	learn: 1.2320076	test: 1.1891042	best: 1.1891042 (0)	total: 2.02s	remaining: 3m 19s
# 99:	learn: 0.4893657	test: 0.5252019	best: 0.5252019 (99)	total: 3m 16s	remaining: 0us
#
# bestTest = 0.5252018667
# bestIteration = 99
#
# 103:	loss: 0.5252019	best: 0.5197572 (75)	total: 2h 39m 45s	remaining: 5h 24m 7s
# 0:	learn: 0.9724752	test: 0.9349800	best: 0.9349800 (0)	total: 2.82s	remaining: 4m 39s
# 99:	learn: 0.4750539	test: 0.5595000	best: 0.5595000 (99)	total: 4m 8s	remaining: 0us
#
# bestTest = 0.5595000127
# bestIteration = 99
#
# 104:	loss: 0.5595000	best: 0.5197572 (75)	total: 2h 43m 54s	remaining: 5h 27m 48s
# 0:	learn: 1.7426132	test: 1.6967696	best: 1.6967696 (0)	total: 6.13s	remaining: 10m 7s
# 99:	learn: 0.9836797	test: 0.9584011	best: 0.9584011 (99)	total: 9m 39s	remaining: 0us
#
# bestTest = 0.9584010625
# bestIteration = 99
#
# 105:	loss: 0.9584011	best: 0.5197572 (75)	total: 2h 53m 34s	remaining: 5h 42m 13s
# 0:	learn: 1.7170101	test: 1.6714810	best: 1.6714810 (0)	total: 5.3s	remaining: 8m 45s
# 99:	learn: 0.6493937	test: 0.6513672	best: 0.6513672 (99)	total: 8m 59s	remaining: 0us
#
# bestTest = 0.6513672055
# bestIteration = 99
#
# 106:	loss: 0.6513672	best: 0.5197572 (75)	total: 3h 2m 33s	remaining: 5h 54m 53s
# 0:	learn: 1.6915430	test: 1.6463268	best: 1.6463268 (0)	total: 5.92s	remaining: 9m 45s
# 99:	learn: 0.5676296	test: 0.5831723	best: 0.5831723 (99)	total: 10m 12s	remaining: 0us
#
# bestTest = 0.5831723432
# bestIteration = 99
#
# 107:	loss: 0.5831723	best: 0.5197572 (75)	total: 3h 12m 46s	remaining: 6h 9m 28s
# 0:	learn: 1.6285117	test: 1.5840713	best: 1.5840713 (0)	total: 6.09s	remaining: 10m 3s
# 99:	learn: 0.4893031	test: 0.5259088	best: 0.5259088 (99)	total: 9m 30s	remaining: 0us
#
# bestTest = 0.5259087902
# bestIteration = 99
#
# 108:	loss: 0.5259088	best: 0.5197572 (75)	total: 3h 22m 16s	remaining: 6h 22m 16s
# 0:	learn: 1.4459115	test: 1.4037493	best: 1.4037493 (0)	total: 5.37s	remaining: 8m 51s
# 99:	learn: 0.3965013	test: 0.4770254	best: 0.4770254 (99)	total: 8m 20s	remaining: 0us
#
# bestTest = 0.4770254234
# bestIteration = 99
#
# 109:	loss: 0.4770254	best: 0.4770254 (109)	total: 3h 30m 37s	remaining: 6h 32m 31s
# 0:	learn: 1.1731924	test: 1.1347962	best: 1.1347962 (0)	total: 5.29s	remaining: 8m 43s
# 99:	learn: 0.3480532	test: 0.4821818	best: 0.4821818 (99)	total: 8m 16s	remaining: 0us
#
# bestTest = 0.482181767
# bestIteration = 99
#
# 110:	loss: 0.4821818	best: 0.4770254 (109)	total: 3h 38m 53s	remaining: 6h 42m 17s
# 0:	learn: 0.8820213	test: 0.8539691	best: 0.8539691 (0)	total: 5.22s	remaining: 8m 36s
# 99:	learn: 0.3436639	test: 0.5771977	best: 0.5771977 (99)	total: 8m 45s	remaining: 0us
#
# bestTest = 0.5771977295
# bestIteration = 99
#
# 111:	loss: 0.5771977	best: 0.4770254 (109)	total: 3h 47m 39s	remaining: 6h 52m 37s
# 0:	learn: 1.7430588	test: 1.6972322	best: 1.6972322 (0)	total: 5.5s	remaining: 9m 4s
# 99:	learn: 1.0025565	test: 0.9750904	best: 0.9750904 (99)	total: 9m 30s	remaining: 0us
#
# bestTest = 0.9750904493
# bestIteration = 99
#
# 112:	loss: 0.9750904	best: 0.4770254 (109)	total: 3h 57m 9s	remaining: 7h 3m 56s
# 0:	learn: 1.7183425	test: 1.6728644	best: 1.6728644 (0)	total: 7.42s	remaining: 12m 15s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-e468cf90c629> in <module>
#      25             "l2_leaf_reg": [1, 3, 5, 7, 9]}
#      26         model =  CatBoostRegressor(loss_function="MultiRMSE", verbose=100, iterations=100)
# ---> 27         grid_search_results = model.grid_search(param_grid, X, y, cv=5, plot=True)
#      28
#      29 #         model.save_model(f"pretrained_models/{station_number}_{pollutant_name}.cbm")
#
# ~/miniconda3/envs/cpur/lib/python3.8/site-packages/catboost/core.py in grid_search(self, param_grid, X, y, cv, partition_random_seed, calc_cv_statistics, search_by_train_test_split, refit, shuffle, stratified, train_size, verbose, plot, log_cout, log_cerr)
#    3772                     raise TypeError('Parameter grid value is not iterable (key={!r}, value={!r})'.format(key, grid[key]))
#    3773
# -> 3774         return self._tune_hyperparams(
#    3775             param_grid=param_grid, X=X, y=y, cv=cv, n_iter=-1,
#    3776             partition_random_seed=partition_random_seed, calc_cv_statistics=calc_cv_statistics,
#
# ~/miniconda3/envs/cpur/lib/python3.8/site-packages/catboost/core.py in _tune_hyperparams(self, param_grid, X, y, cv, n_iter, partition_random_seed, calc_cv_statistics, search_by_train_test_split, refit, shuffle, stratified, train_size, verbose, plot, log_cout, log_cerr)
#    3669
#    3670         with log_fixup(log_cout, log_cerr), plot_wrapper(plot, [_get_train_dir(params)]):
# -> 3671             cv_result = self._object._tune_hyperparams(
#    3672                 param_grid, train_params["train_pool"], params, n_iter,
#    3673                 fold_count, partition_random_seed, shuffle, stratified, train_size,
#
# _catboost.pyx in _catboost._CatBoost._tune_hyperparams()
#
# _catboost.pyx in _catboost._CatBoost._tune_hyperparams()
#
# KeyboardInterrupt:

# %%
import shutil

shutil.make_archive("models",  "zip", "pretrained_models/")

# %%
#!c1.8
metrics_df.groupby(level=1).mean()

# %%
#!c1.8
# With nulls in pollutant concentrations removed
metrics_df_2.groupby(level=1).mean()

# %%
#!c1.8
metrics_df_2 = pd.concat(metrics)

# %%
metrics_df_2.groupby(level=0).mean()

# %%
#!c1.8
metrics_df.groupby(level=0).mean()

# %%
#!c1.8
metrics_df.groupby(level=1).mean()

# %%
metrics_df_2.groupby(level=1).mean()

# %%
#!c1.8
metrics_df.groupby(level=2).mean()

# %%
#!c1.8
metrics_df_2.groupby(level=2).mean()

# %%
pd.concat(f_imp).reset_index().drop("level_2", axis=1).drop_duplicates(subset="features").sort_values("importance", ascending=False).head(40)
